# %%
# Import the required models
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from sklearn import linear_model
# %matplotlib inline

# %%
df = pd.read_csv('RELIANCE.NS new.csv')
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     1996-01-01    15.859429    15.944529    15.754989    15.917452
# 1     1996-01-02    15.878770    15.956133    15.677626    15.793671
# 2     1996-01-03    16.052837    16.783918    15.878770    15.913584
# 3     1996-01-04    15.762726    15.813012    15.553845    15.766594
# 4     1996-01-05    15.704703    15.704703    15.522900    15.658285
# ...          ...          ...          ...          ...          ...
# 6945  2023-08-03  2475.300049  2500.899902  2458.050049  2475.899902
# 6946  2023-08-04  2498.800049  2516.000000  2471.600098  2509.550049
# 6947  2023-08-07  2521.000000  2528.399902  2505.000000  2523.850098
# 6948  2023-08-08  2528.000000  2534.449951  2499.550049  2508.649902
# 6949  2023-08-09  2504.850098  2529.000000  2481.100098  2525.199951
#
#         Adj Close       Volume
# 0       10.477993   48051995.0
# 1       10.396508   77875009.0
# 2       10.475446   96602936.0
# ...

# %%
df.isna().sum()
# Out:
# Date          0
# Open         10
# High         10
# Low          10
# Close        10
# Adj Close    10
# Volume       10
# dtype: int64

# %%
# Convert the 'Date' column to datetime format
# df['DateNew'] = pd.to_datetime(df['Date'])
# df

# %%
plt.figure(figsize=(12, 6)) 
plt.plot(df['Date'], df['Open'],   )
# linewidth=2, , marker='o',markersize=6,linestyle='-',
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Open Price Over Time')
# Out:
# Text(0.5, 1.0, 'Open Price Over Time')

# %%
plt.figure(figsize=(12, 6)) 
plt.plot(df['Date'], df['Close'])
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Closing Price Over Time')
# Out:
# Text(0.5, 1.0, 'Closing Price Over Time')

# %%
# Extract year from the 'Date' column and group by year
df['Year'] = df['Date'].dt.year
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Extract year from the 'Date' column and group by year
# ----> 2 df['Year'] = df['Date'].dt.year
#       3 df
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])
# Extract year from the 'Date' column and group by year
df['Year'] = df['Date'].dt.year
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    1996-01-01    15.859429    15.944529    15.754989    15.917452
# 1    1996-01-02    15.878770    15.956133    15.677626    15.793671
# 2    1996-01-03    16.052837    16.783918    15.878770    15.913584
# 3    1996-01-04    15.762726    15.813012    15.553845    15.766594
# 4    1996-01-05    15.704703    15.704703    15.522900    15.658285
# ...         ...          ...          ...          ...          ...
# 6945 2023-08-03  2475.300049  2500.899902  2458.050049  2475.899902
# 6946 2023-08-04  2498.800049  2516.000000  2471.600098  2509.550049
# 6947 2023-08-07  2521.000000  2528.399902  2505.000000  2523.850098
# 6948 2023-08-08  2528.000000  2534.449951  2499.550049  2508.649902
# 6949 2023-08-09  2504.850098  2529.000000  2481.100098  2525.199951
#
#         Adj Close       Volume    DateNew  Year
# 0       10.477993   48051995.0 1996-01-01  1996
# 1       10.396508   77875009.0 1996-01-02  1996
# ...

# %%
yearly_df= df.groupby('Year').agg({'Open': 'mean', 'Close': 'mean'}).reset_index()
yearly_df
# Out:
#     Year         Open        Close
# 0   1996    16.201097    16.179645
# 1   1997    25.356932    25.343979
# 2   1998    22.458411    22.375653
# 3   1999    27.447321    27.431789
# 4   2000    50.363390    50.288705
# 5   2001    51.762979    51.765914
# 6   2002    43.271715    43.133618
# 7   2003    55.606850    55.686862
# 8   2004    79.883293    79.540337
# 9   2005   102.078531   102.020230
# 10  2006   245.847440   246.105268
# 11  2007   470.967554   471.492166
# 12  2008   524.970701   522.018958
# 13  2009   459.981399   459.779099
# 14  2010   514.891840   513.674381
# 15  2011   441.424980   440.201818
# 16  2012   382.301975   382.388907
# 17  2013   420.771486   420.320319
# 18  2014   473.435055   472.924831
# 19  2015   453.807706   453.562772
# 20  2016   502.390784   502.124509
# 21  2017   732.841801   732.590353
# 22  2018  1031.353876  1031.413272
# 23  2019  1310.830608  1309.483088
# 24  2020  1743.920063  1740.393333
# 25  2021  2202.718147  2199.715526
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(yearly_df['Year'], yearly_df['Open'])
plt.plot(yearly_df['Year'], yearly_df['Close'])
plt.xlabel('Year')
plt.ylabel('Open/Closing Price Avg')
# Out:
# Text(0, 0.5, 'Open/Closing Price Avg')
